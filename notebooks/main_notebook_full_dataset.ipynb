# %%
# imports
import ijson
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor

# %%
# set options for pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Dataset Extraction from json-format

# %%
def extract_json_data(json_event, no_of_entries):
    return pd.json_normalize(json_event)

def extract_json_data_into_dataframe(json_file_path: str, no_of_entries: int) -> pd.DataFrame:
    df = pd.DataFrame()
    with open(json_file_path, 'r') as f:
        json_events = ijson.items(f, 'item')
        with ThreadPoolExecutor() as executor:
            futures = []
            for i, json_event in enumerate(json_events):
                future = executor.submit(extract_json_data, json_event, no_of_entries)
                futures.append(future)
                if i % no_of_entries == 0:
                    print(f'Extracted {i} events from Stuttgart.')


            for i, future in enumerate(futures):
                single_df = future.result()
                df = pd.concat([df, single_df], ignore_index=True)
                if i % no_of_entries*50 == 0:
                    print(f'Added {i} events to dataframe.')

    return df

df = extract_json_data_into_dataframe('stuttgart_events.json', 100)
print(df)
# Out:
# Extracted 0 events from Stuttgart.
# Extracted 100 events from Stuttgart.
# Extracted 200 events from Stuttgart.
# Extracted 300 events from Stuttgart.
# Extracted 400 events from Stuttgart.
# Extracted 500 events from Stuttgart.
# Extracted 600 events from Stuttgart.
# Extracted 700 events from Stuttgart.
# Extracted 800 events from Stuttgart.
# Extracted 900 events from Stuttgart.
# Extracted 1000 events from Stuttgart.
# Extracted 1100 events from Stuttgart.
# Extracted 1200 events from Stuttgart.
# Extracted 1300 events from Stuttgart.
# Extracted 1400 events from Stuttgart.
# Extracted 1500 events from Stuttgart.
# Extracted 1600 events from Stuttgart.
# Extracted 1700 events from Stuttgart.
# Extracted 1800 events from Stuttgart.
# Extracted 1900 events from Stuttgart.
# Extracted 2000 events from Stuttgart.
# Extracted 2100 events from Stuttgart.
# Extracted 2200 events from Stuttgart.
# Extracted 2300 events from Stuttgart.
# Extracted 2400 events from Stuttgart.
# Extracted 2500 events from Stuttgart.
# Extracted 2600 events from Stuttgart.
# Extracted 2700 events from Stuttgart.
# Extracted 2800 events from Stuttgart.
# Extracted 2900 events from Stuttgart.
# Extracted 3000 events from Stuttgart.
# Extracted 3100 events from Stuttgart.
# Extracted 3200 events from Stuttgart.
# Extracted 3300 events from Stuttgart.
# Extracted 3400 events from Stuttgart.
# Extracted 3500 events from Stuttgart.
# Extracted 3600 events from Stuttgart.
# Extracted 3700 events from Stuttgart.
# Extracted 3800 events from Stuttgart.
# Extracted 3900 events from Stuttgart.
# Extracted 4000 events from Stuttgart.
# Extracted 4100 events from Stuttgart.
# Extracted 4200 events from Stuttgart.
# Extracted 4300 events from Stuttgart.
# Extracted 4400 events from Stuttgart.
# Extracted 4500 events from Stuttgart.
# Extracted 4600 events from Stuttgart.
# Extracted 4700 events from Stuttgart.
# Extracted 4800 events from Stuttgart.
# Extracted 4900 events from Stuttgart.
# Extracted 5000 events from Stuttgart.
# Extracted 5100 events from Stuttgart.
# Extracted 5200 events from Stuttgart.
# Extracted 5300 events from Stuttgart.
# Extracted 5400 events from Stuttgart.
# Extracted 5500 events from Stuttgart.
# Extracted 5600 events from Stuttgart.
# Extracted 5700 events from Stuttgart.
# Extracted 5800 events from Stuttgart.
# Extracted 5900 events from Stuttgart.
# Extracted 6000 events from Stuttgart.
# Extracted 6100 events from Stuttgart.
# Extracted 6200 events from Stuttgart.
# Extracted 6300 events from Stuttgart.
# Extracted 6400 events from Stuttgart.
# Extracted 6500 events from Stuttgart.
# Extracted 6600 events from Stuttgart.
# Extracted 6700 events from Stuttgart.
# Extracted 6800 events from Stuttgart.
# Extracted 6900 events from Stuttgart.
# Extracted 7000 events from Stuttgart.
# Extracted 7100 events from Stuttgart.
# Extracted 7200 events from Stuttgart.
# Extracted 7300 events from Stuttgart.
# Extracted 7400 events from Stuttgart.
# Extracted 7500 events from Stuttgart.
# Extracted 7600 events from Stuttgart.
# Extracted 7700 events from Stuttgart.
# Extracted 7800 events from Stuttgart.
# Extracted 7900 events from Stuttgart.
# Extracted 8000 events from Stuttgart.
# Extracted 8100 events from Stuttgart.
# Extracted 8200 events from Stuttgart.
# Extracted 8300 events from Stuttgart.
# Extracted 8400 events from Stuttgart.
# Extracted 8500 events from Stuttgart.
# Extracted 8600 events from Stuttgart.
# Extracted 8700 events from Stuttgart.
# Extracted 8800 events from Stuttgart.
# Extracted 8900 events from Stuttgart.
# Extracted 9000 events from Stuttgart.
# Extracted 9100 events from Stuttgart.
# Extracted 9200 events from Stuttgart.
# Extracted 9300 events from Stuttgart.
# Extracted 9400 events from Stuttgart.
# Extracted 9500 events from Stuttgart.
# Extracted 9600 events from Stuttgart.
# Extracted 9700 events from Stuttgart.
# Extracted 9800 events from Stuttgart.
# Extracted 9900 events from Stuttgart.
# Extracted 10000 events from Stuttgart.
# Extracted 10100 events from Stuttgart.
# Extracted 10200 events from Stuttgart.
# Extracted 10300 events from Stuttgart.
# Extracted 10400 events from Stuttgart.
# Extracted 10500 events from Stuttgart.
# Extracted 10600 events from Stuttgart.
# Extracted 10700 events from Stuttgart.
# Extracted 10800 events from Stuttgart.
# Extracted 10900 events from Stuttgart.
# Extracted 11000 events from Stuttgart.
# Extracted 11100 events from Stuttgart.
# Extracted 11200 events from Stuttgart.
# Extracted 11300 events from Stuttgart.
# Extracted 11400 events from Stuttgart.
# Extracted 11500 events from Stuttgart.
# Extracted 11600 events from Stuttgart.
# Extracted 11700 events from Stuttgart.
# Extracted 11800 events from Stuttgart.
# Extracted 11900 events from Stuttgart.
# Extracted 12000 events from Stuttgart.
# Extracted 12100 events from Stuttgart.
# Extracted 12200 events from Stuttgart.
# Extracted 12300 events from Stuttgart.
# Extracted 12400 events from Stuttgart.
# Extracted 12500 events from Stuttgart.
# Extracted 12600 events from Stuttgart.
# Extracted 12700 events from Stuttgart.
# Extracted 12800 events from Stuttgart.
# Extracted 12900 events from Stuttgart.
# Extracted 13000 events from Stuttgart.
# Extracted 13100 events from Stuttgart.
# Extracted 13200 events from Stuttgart.
# Extracted 13300 events from Stuttgart.
# Extracted 13400 events from Stuttgart.
# Extracted 13500 events from Stuttgart.
# Extracted 13600 events from Stuttgart.
# Extracted 13700 events from Stuttgart.
# Extracted 13800 events from Stuttgart.
# Extracted 13900 events from Stuttgart.
# Extracted 14000 events from Stuttgart.
# Extracted 14100 events from Stuttgart.
# Extracted 14200 events from Stuttgart.
# Extracted 14300 events from Stuttgart.
# Extracted 14400 events from Stuttgart.
# Extracted 14500 events from Stuttgart.
# Extracted 14600 events from Stuttgart.
# Extracted 14700 events from Stuttgart.
# Extracted 14800 events from Stuttgart.
# Extracted 14900 events from Stuttgart.
# Extracted 15000 events from Stuttgart.
# Extracted 15100 events from Stuttgart.
# Extracted 15200 events from Stuttgart.
# Extracted 15300 events from Stuttgart.
# Extracted 15400 events from Stuttgart.
# Extracted 15500 events from Stuttgart.
# Extracted 15600 events from Stuttgart.
# Extracted 15700 events from Stuttgart.
# Extracted 15800 events from Stuttgart.
# Extracted 15900 events from Stuttgart.
# Extracted 16000 events from Stuttgart.
# Extracted 16100 events from Stuttgart.
# Extracted 16200 events from Stuttgart.
# Extracted 16300 events from Stuttgart.
# Extracted 16400 events from Stuttgart.
# Extracted 16500 events from Stuttgart.
# Extracted 16600 events from Stuttgart.
# Extracted 16700 events from Stuttgart.
# Extracted 16800 events from Stuttgart.
# Extracted 16900 events from Stuttgart.
# Extracted 17000 events from Stuttgart.
# Extracted 17100 events from Stuttgart.
# Extracted 17200 events from Stuttgart.
# Extracted 17300 events from Stuttgart.
# Extracted 17400 events from Stuttgart.
# Extracted 17500 events from Stuttgart.
# Extracted 17600 events from Stuttgart.
# Extracted 17700 events from Stuttgart.
# Extracted 17800 events from Stuttgart.
# Extracted 17900 events from Stuttgart.
# Extracted 18000 events from Stuttgart.
# Extracted 18100 events from Stuttgart.
# Extracted 18200 events from Stuttgart.
# Extracted 18300 events from Stuttgart.
# Extracted 18400 events from Stuttgart.
# Extracted 18500 events from Stuttgart.
# Extracted 18600 events from Stuttgart.
# Extracted 18700 events from Stuttgart.
# Extracted 18800 events from Stuttgart.
# Extracted 18900 events from Stuttgart.
# Extracted 19000 events from Stuttgart.
# Extracted 19100 events from Stuttgart.
# Extracted 19200 events from Stuttgart.
# Extracted 19300 events from Stuttgart.
# Extracted 19400 events from Stuttgart.
# Extracted 19500 events from Stuttgart.
# Extracted 19600 events from Stuttgart.
# Extracted 19700 events from Stuttgart.
# Extracted 19800 events from Stuttgart.
# Extracted 19900 events from Stuttgart.
# Extracted 20000 events from Stuttgart.
# Extracted 20100 events from Stuttgart.
# Extracted 20200 events from Stuttgart.
# Extracted 20300 events from Stuttgart.
# Extracted 20400 events from Stuttgart.
# Extracted 20500 events from Stuttgart.
# Extracted 20600 events from Stuttgart.
# Extracted 20700 events from Stuttgart.
# Extracted 20800 events from Stuttgart.
# Extracted 20900 events from Stuttgart.
# Extracted 21000 events from Stuttgart.
# Extracted 21100 events from Stuttgart.
# Extracted 21200 events from Stuttgart.
# Extracted 21300 events from Stuttgart.
# Extracted 21400 events from Stuttgart.
# Extracted 21500 events from Stuttgart.
# Extracted 21600 events from Stuttgart.
# Extracted 21700 events from Stuttgart.
# Extracted 21800 events from Stuttgart.
# Extracted 21900 events from Stuttgart.
# Extracted 22000 events from Stuttgart.
# Extracted 22100 events from Stuttgart.
# Extracted 22200 events from Stuttgart.
# Extracted 22300 events from Stuttgart.
# Extracted 22400 events from Stuttgart.
# Extracted 22500 events from Stuttgart.
# Extracted 22600 events from Stuttgart.
# Extracted 22700 events from Stuttgart.
# Extracted 22800 events from Stuttgart.
# Extracted 22900 events from Stuttgart.
# Extracted 23000 events from Stuttgart.
# Extracted 23100 events from Stuttgart.
# Extracted 23200 events from Stuttgart.
# Extracted 23300 events from Stuttgart.
# Extracted 23400 events from Stuttgart.
# Extracted 23500 events from Stuttgart.
# Extracted 23600 events from Stuttgart.
# Extracted 23700 events from Stuttgart.
# Extracted 23800 events from Stuttgart.
# Extracted 23900 events from Stuttgart.
# Extracted 24000 events from Stuttgart.
# Extracted 24100 events from Stuttgart.
# Extracted 24200 events from Stuttgart.
# Extracted 24300 events from Stuttgart.
# Extracted 24400 events from Stuttgart.
# Extracted 24500 events from Stuttgart.
# Extracted 24600 events from Stuttgart.
# Extracted 24700 events from Stuttgart.
# Extracted 24800 events from Stuttgart.
# Extracted 24900 events from Stuttgart.
# Extracted 25000 events from Stuttgart.
# Extracted 25100 events from Stuttgart.
# Extracted 25200 events from Stuttgart.
# Extracted 25300 events from Stuttgart.
# Extracted 25400 events from Stuttgart.
# Extracted 25500 events from Stuttgart.
# Extracted 25600 events from Stuttgart.
# Extracted 25700 events from Stuttgart.
# Extracted 25800 events from Stuttgart.
# Extracted 25900 events from Stuttgart.
# Extracted 26000 events from Stuttgart.
# Extracted 26100 events from Stuttgart.
# Extracted 26200 events from Stuttgart.
# Extracted 26300 events from Stuttgart.
# Extracted 26400 events from Stuttgart.
# Extracted 26500 events from Stuttgart.
# Extracted 26600 events from Stuttgart.
# Extracted 26700 events from Stuttgart.
# Extracted 26800 events from Stuttgart.
# Extracted 26900 events from Stuttgart.
# Extracted 27000 events from Stuttgart.
# Extracted 27100 events from Stuttgart.
# Extracted 27200 events from Stuttgart.
# Extracted 27300 events from Stuttgart.
# Extracted 27400 events from Stuttgart.
# Extracted 27500 events from Stuttgart.
# Extracted 27600 events from Stuttgart.
# Extracted 27700 events from Stuttgart.
# Extracted 27800 events from Stuttgart.
# Extracted 27900 events from Stuttgart.
# Extracted 28000 events from Stuttgart.
# Extracted 28100 events from Stuttgart.
# Extracted 28200 events from Stuttgart.
# Extracted 28300 events from Stuttgart.
# Extracted 28400 events from Stuttgart.
# Extracted 28500 events from Stuttgart.
# Extracted 28600 events from Stuttgart.
# Extracted 28700 events from Stuttgart.
# Extracted 28800 events from Stuttgart.
# Extracted 28900 events from Stuttgart.
# Extracted 29000 events from Stuttgart.
# Extracted 29100 events from Stuttgart.
# Extracted 29200 events from Stuttgart.
# Extracted 29300 events from Stuttgart.
# Extracted 29400 events from Stuttgart.
# Extracted 29500 events from Stuttgart.
# Extracted 29600 events from Stuttgart.
# Extracted 29700 events from Stuttgart.
# Extracted 29800 events from Stuttgart.
# Extracted 29900 events from Stuttgart.
# Extracted 30000 events from Stuttgart.
# Extracted 30100 events from Stuttgart.
# Extracted 30200 events from Stuttgart.
# Extracted 30300 events from Stuttgart.
# Extracted 30400 events from Stuttgart.
# Extracted 30500 events from Stuttgart.
# Extracted 30600 events from Stuttgart.
# Extracted 30700 events from Stuttgart.
# Extracted 30800 events from Stuttgart.
# Extracted 30900 events from Stuttgart.
# Extracted 31000 events from Stuttgart.
# Extracted 31100 events from Stuttgart.
# Extracted 31200 events from Stuttgart.
# Extracted 31300 events from Stuttgart.
# Extracted 31400 events from Stuttgart.
# Extracted 31500 events from Stuttgart.
# Extracted 31600 events from Stuttgart.
# Extracted 31700 events from Stuttgart.
# Extracted 31800 events from Stuttgart.
# Extracted 31900 events from Stuttgart.
# Extracted 32000 events from Stuttgart.
# Extracted 32100 events from Stuttgart.
# Extracted 32200 events from Stuttgart.
# Extracted 32300 events from Stuttgart.
# Extracted 32400 events from Stuttgart.
# Extracted 32500 events from Stuttgart.
# Extracted 32600 events from Stuttgart.
# Extracted 32700 events from Stuttgart.
# Extracted 32800 events from Stuttgart.
# Extracted 32900 events from Stuttgart.
# Extracted 33000 events from Stuttgart.
# Extracted 33100 events from Stuttgart.
# Extracted 33200 events from Stuttgart.
# Extracted 33300 events from Stuttgart.
# Extracted 33400 events from Stuttgart.
# Extracted 33500 events from Stuttgart.
# Extracted 33600 events from Stuttgart.
# Extracted 33700 events from Stuttgart.
# Extracted 33800 events from Stuttgart.
# Extracted 33900 events from Stuttgart.
# Extracted 34000 events from Stuttgart.
# Extracted 34100 events from Stuttgart.
# Extracted 34200 events from Stuttgart.
# Extracted 34300 events from Stuttgart.
# Extracted 34400 events from Stuttgart.
# Extracted 34500 events from Stuttgart.
# Extracted 34600 events from Stuttgart.
# Extracted 34700 events from Stuttgart.
# Extracted 34800 events from Stuttgart.
# Extracted 34900 events from Stuttgart.
# Extracted 35000 events from Stuttgart.
# Extracted 35100 events from Stuttgart.
# Extracted 35200 events from Stuttgart.
# Extracted 35300 events from Stuttgart.
# Extracted 35400 events from Stuttgart.
# Extracted 35500 events from Stuttgart.
# Extracted 35600 events from Stuttgart.
# Extracted 35700 events from Stuttgart.
# Extracted 35800 events from Stuttgart.
# Extracted 35900 events from Stuttgart.
# Extracted 36000 events from Stuttgart.
# Extracted 36100 events from Stuttgart.
# Extracted 36200 events from Stuttgart.
# Extracted 36300 events from Stuttgart.
# Extracted 36400 events from Stuttgart.
# Extracted 36500 events from Stuttgart.
# Extracted 36600 events from Stuttgart.
# Extracted 36700 events from Stuttgart.
# Extracted 36800 events from Stuttgart.
# Extracted 36900 events from Stuttgart.
# Extracted 37000 events from Stuttgart.
# Extracted 37100 events from Stuttgart.
# Extracted 37200 events from Stuttgart.
# Extracted 37300 events from Stuttgart.
# Extracted 37400 events from Stuttgart.
# Extracted 37500 events from Stuttgart.
# Extracted 37600 events from Stuttgart.
# Extracted 37700 events from Stuttgart.
# Extracted 37800 events from Stuttgart.
# Extracted 37900 events from Stuttgart.
# Extracted 38000 events from Stuttgart.
# Extracted 38100 events from Stuttgart.
# Extracted 38200 events from Stuttgart.
# Extracted 38300 events from Stuttgart.
# Extracted 38400 events from Stuttgart.
# Extracted 38500 events from Stuttgart.
# Extracted 38600 events from Stuttgart.
# Extracted 38700 events from Stuttgart.
# Extracted 38800 events from Stuttgart.
# Extracted 38900 events from Stuttgart.
# Extracted 39000 events from Stuttgart.
# Extracted 39100 events from Stuttgart.
# Extracted 39200 events from Stuttgart.
# Extracted 39300 events from Stuttgart.
# Extracted 39400 events from Stuttgart.
# Extracted 39500 events from Stuttgart.
# Extracted 39600 events from Stuttgart.
# Extracted 39700 events from Stuttgart.
# Extracted 39800 events from Stuttgart.
# Extracted 39900 events from Stuttgart.
# Extracted 40000 events from Stuttgart.
# Extracted 40100 events from Stuttgart.
# Extracted 40200 events from Stuttgart.
# Extracted 40300 events from Stuttgart.
# Extracted 40400 events from Stuttgart.
# Extracted 40500 events from Stuttgart.
# Extracted 40600 events from Stuttgart.
# Extracted 40700 events from Stuttgart.
# Extracted 40800 events from Stuttgart.
# Extracted 40900 events from Stuttgart.
# Extracted 41000 events from Stuttgart.
# Extracted 41100 events from Stuttgart.
# Extracted 41200 events from Stuttgart.
# Extracted 41300 events from Stuttgart.
# Extracted 41400 events from Stuttgart.
# Extracted 41500 events from Stuttgart.
# Extracted 41600 events from Stuttgart.
# Extracted 41700 events from Stuttgart.
# Extracted 41800 events from Stuttgart.
# Extracted 41900 events from Stuttgart.
# Extracted 42000 events from Stuttgart.
# Extracted 42100 events from Stuttgart.
# Extracted 42200 events from Stuttgart.
# Extracted 42300 events from Stuttgart.
# Extracted 42400 events from Stuttgart.
# Extracted 42500 events from Stuttgart.
# Extracted 42600 events from Stuttgart.
# Extracted 42700 events from Stuttgart.
# Extracted 42800 events from Stuttgart.
# Extracted 42900 events from Stuttgart.
# Extracted 43000 events from Stuttgart.
# Extracted 43100 events from Stuttgart.
# Extracted 43200 events from Stuttgart.
# Extracted 43300 events from Stuttgart.
# Extracted 43400 events from Stuttgart.
# Extracted 43500 events from Stuttgart.
# Extracted 43600 events from Stuttgart.
# Extracted 43700 events from Stuttgart.
# Extracted 43800 events from Stuttgart.
# Extracted 43900 events from Stuttgart.
# Extracted 44000 events from Stuttgart.
# Extracted 44100 events from Stuttgart.
# Extracted 44200 events from Stuttgart.
# Extracted 44300 events from Stuttgart.
# Extracted 44400 events from Stuttgart.
# Extracted 44500 events from Stuttgart.
# Extracted 44600 events from Stuttgart.
# Extracted 44700 events from Stuttgart.
# Extracted 44800 events from Stuttgart.
# Extracted 44900 events from Stuttgart.
# Extracted 45000 events from Stuttgart.
# Extracted 45100 events from Stuttgart.
# Extracted 45200 events from Stuttgart.
# Extracted 45300 events from Stuttgart.
# Extracted 45400 events from Stuttgart.
# Extracted 45500 events from Stuttgart.
# Extracted 45600 events from Stuttgart.
# Extracted 45700 events from Stuttgart.
# Extracted 45800 events from Stuttgart.
# Extracted 45900 events from Stuttgart.
# Extracted 46000 events from Stuttgart.
# Extracted 46100 events from Stuttgart.
# Extracted 46200 events from Stuttgart.
# Extracted 46300 events from Stuttgart.
# Extracted 46400 events from Stuttgart.
# Extracted 46500 events from Stuttgart.
# Extracted 46600 events from Stuttgart.
# Extracted 46700 events from Stuttgart.
# Extracted 46800 events from Stuttgart.
# Extracted 46900 events from Stuttgart.
# Extracted 47000 events from Stuttgart.
# Extracted 47100 events from Stuttgart.
# Extracted 47200 events from Stuttgart.
# Extracted 47300 events from Stuttgart.
# Extracted 47400 events from Stuttgart.
# Extracted 47500 events from Stuttgart.
# Extracted 47600 events from Stuttgart.
# Extracted 47700 events from Stuttgart.
# Extracted 47800 events from Stuttgart.
# Extracted 47900 events from Stuttgart.
# Extracted 48000 events from Stuttgart.
# Extracted 48100 events from Stuttgart.
# Extracted 48200 events from Stuttgart.
# Extracted 48300 events from Stuttgart.
# Extracted 48400 events from Stuttgart.
# Extracted 48500 events from Stuttgart.
# Extracted 48600 events from Stuttgart.
# Extracted 48700 events from Stuttgart.
# Extracted 48800 events from Stuttgart.
# Extracted 48900 events from Stuttgart.
# Extracted 49000 events from Stuttgart.
# Extracted 49100 events from Stuttgart.
# Extracted 49200 events from Stuttgart.
# Extracted 49300 events from Stuttgart.
# Extracted 49400 events from Stuttgart.
# Extracted 49500 events from Stuttgart.
# Extracted 49600 events from Stuttgart.
# Extracted 49700 events from Stuttgart.
# Extracted 49800 events from Stuttgart.
# Extracted 49900 events from Stuttgart.
# Extracted 50000 events from Stuttgart.
# Extracted 50100 events from Stuttgart.
# Extracted 50200 events from Stuttgart.
# Extracted 50300 events from Stuttgart.
# Extracted 50400 events from Stuttgart.
# Extracted 50500 events from Stuttgart.
# Extracted 50600 events from Stuttgart.
# Extracted 50700 events from Stuttgart.
# Extracted 50800 events from Stuttgart.
# Extracted 50900 events from Stuttgart.
# Extracted 51000 events from Stuttgart.
# Extracted 51100 events from Stuttgart.
# Extracted 51200 events from Stuttgart.
# Extracted 51300 events from Stuttgart.
# Extracted 51400 events from Stuttgart.
# Extracted 51500 events from Stuttgart.
# Extracted 51600 events from Stuttgart.
# Extracted 51700 events from Stuttgart.
# Extracted 51800 events from Stuttgart.
# Extracted 51900 events from Stuttgart.
# Extracted 52000 events from Stuttgart.
# Extracted 52100 events from Stuttgart.
# Extracted 52200 events from Stuttgart.
# Extracted 52300 events from Stuttgart.
# Extracted 52400 events from Stuttgart.
# Extracted 52500 events from Stuttgart.
# Extracted 52600 events from Stuttgart.
# Extracted 52700 events from Stuttgart.
# Extracted 52800 events from Stuttgart.
# Extracted 52900 events from Stuttgart.
# Extracted 53000 events from Stuttgart.
# Extracted 53100 events from Stuttgart.
# Extracted 53200 events from Stuttgart.
# Extracted 53300 events from Stuttgart.
# Extracted 53400 events from Stuttgart.
# Extracted 53500 events from Stuttgart.
# Extracted 53600 events from Stuttgart.
# Extracted 53700 events from Stuttgart.
# Extracted 53800 events from Stuttgart.
# Extracted 53900 events from Stuttgart.
# Extracted 54000 events from Stuttgart.
# Extracted 54100 events from Stuttgart.
# Extracted 54200 events from Stuttgart.
# Extracted 54300 events from Stuttgart.
# Extracted 54400 events from Stuttgart.
# Extracted 54500 events from Stuttgart.
# Extracted 54600 events from Stuttgart.
# Extracted 54700 events from Stuttgart.
# Extracted 54800 events from Stuttgart.
# Extracted 54900 events from Stuttgart.
# Extracted 55000 events from Stuttgart.
# Extracted 55100 events from Stuttgart.
# Extracted 55200 events from Stuttgart.
# Extracted 55300 events from Stuttgart.
# Extracted 55400 events from Stuttgart.
# Extracted 55500 events from Stuttgart.
# Extracted 55600 events from Stuttgart.
# Extracted 55700 events from Stuttgart.
# Extracted 55800 events from Stuttgart.
# Extracted 55900 events from Stuttgart.
# Extracted 56000 events from Stuttgart.
# Extracted 56100 events from Stuttgart.
# Extracted 56200 events from Stuttgart.
# Extracted 56300 events from Stuttgart.
# Extracted 56400 events from Stuttgart.
# Extracted 56500 events from Stuttgart.
# Extracted 56600 events from Stuttgart.
# Extracted 56700 events from Stuttgart.
# Extracted 56800 events from Stuttgart.
# Extracted 56900 events from Stuttgart.
# Extracted 57000 events from Stuttgart.
# Extracted 57100 events from Stuttgart.
# Extracted 57200 events from Stuttgart.
# Extracted 57300 events from Stuttgart.
# Extracted 57400 events from Stuttgart.
# Extracted 57500 events from Stuttgart.
# Extracted 57600 events from Stuttgart.
# Extracted 57700 events from Stuttgart.
# Extracted 57800 events from Stuttgart.
# Extracted 57900 events from Stuttgart.
# Extracted 58000 events from Stuttgart.
# Extracted 58100 events from Stuttgart.
# Extracted 58200 events from Stuttgart.
# Extracted 58300 events from Stuttgart.
# Extracted 58400 events from Stuttgart.
# Extracted 58500 events from Stuttgart.
# Extracted 58600 events from Stuttgart.
# Extracted 58700 events from Stuttgart.
# Extracted 58800 events from Stuttgart.
# Extracted 58900 events from Stuttgart.
# Extracted 59000 events from Stuttgart.
# Extracted 59100 events from Stuttgart.
# Extracted 59200 events from Stuttgart.
# Extracted 59300 events from Stuttgart.
# Extracted 59400 events from Stuttgart.
# Extracted 59500 events from Stuttgart.
# Extracted 59600 events from Stuttgart.
# Extracted 59700 events from Stuttgart.
# Extracted 59800 events from Stuttgart.
# Extracted 59900 events from Stuttgart.
# Extracted 60000 events from Stuttgart.
# Extracted 60100 events from Stuttgart.
# Extracted 60200 events from Stuttgart.
# Extracted 60300 events from Stuttgart.
# Extracted 60400 events from Stuttgart.
# Extracted 60500 events from Stuttgart.
# Extracted 60600 events from Stuttgart.
# Extracted 60700 events from Stuttgart.
# Extracted 60800 events from Stuttgart.
# Extracted 60900 events from Stuttgart.
# Extracted 61000 events from Stuttgart.
# Extracted 61100 events from Stuttgart.
# Extracted 61200 events from Stuttgart.
# Extracted 61300 events from Stuttgart.
# Extracted 61400 events from Stuttgart.
# Extracted 61500 events from Stuttgart.
# Extracted 61600 events from Stuttgart.
# Extracted 61700 events from Stuttgart.
# Extracted 61800 events from Stuttgart.
# Extracted 61900 events from Stuttgart.
# Extracted 62000 events from Stuttgart.
# Extracted 62100 events from Stuttgart.
# Extracted 62200 events from Stuttgart.
# Extracted 62300 events from Stuttgart.
# Extracted 62400 events from Stuttgart.
# Extracted 62500 events from Stuttgart.
# Extracted 62600 events from Stuttgart.
# Extracted 62700 events from Stuttgart.
# Extracted 62800 events from Stuttgart.
# Extracted 62900 events from Stuttgart.
# Extracted 63000 events from Stuttgart.
# Extracted 63100 events from Stuttgart.
# Extracted 63200 events from Stuttgart.
# Extracted 63300 events from Stuttgart.
# Extracted 63400 events from Stuttgart.
# Extracted 63500 events from Stuttgart.
# Extracted 63600 events from Stuttgart.
# Extracted 63700 events from Stuttgart.
# Extracted 63800 events from Stuttgart.
# Extracted 63900 events from Stuttgart.
# Extracted 64000 events from Stuttgart.
# Extracted 64100 events from Stuttgart.
# Extracted 64200 events from Stuttgart.
# Extracted 64300 events from Stuttgart.
# Extracted 64400 events from Stuttgart.
# Extracted 64500 events from Stuttgart.
# Extracted 64600 events from Stuttgart.
# Extracted 64700 events from Stuttgart.
# Extracted 64800 events from Stuttgart.
# Extracted 64900 events from Stuttgart.
# Extracted 65000 events from Stuttgart.
# Extracted 65100 events from Stuttgart.
# Extracted 65200 events from Stuttgart.
# Extracted 65300 events from Stuttgart.
# Extracted 65400 events from Stuttgart.
# Extracted 65500 events from Stuttgart.
# Extracted 65600 events from Stuttgart.
# Extracted 65700 events from Stuttgart.
# Extracted 65800 events from Stuttgart.
# Extracted 65900 events from Stuttgart.
# Extracted 66000 events from Stuttgart.
# Extracted 66100 events from Stuttgart.
# Extracted 66200 events from Stuttgart.
# Extracted 66300 events from Stuttgart.
# Extracted 66400 events from Stuttgart.
# Extracted 66500 events from Stuttgart.
# Extracted 66600 events from Stuttgart.
# Extracted 66700 events from Stuttgart.
# Extracted 66800 events from Stuttgart.
# Extracted 66900 events from Stuttgart.
# Extracted 67000 events from Stuttgart.
# Extracted 67100 events from Stuttgart.
# Extracted 67200 events from Stuttgart.
# Extracted 67300 events from Stuttgart.
# Extracted 67400 events from Stuttgart.
# Extracted 67500 events from Stuttgart.
# Extracted 67600 events from Stuttgart.
# Extracted 67700 events from Stuttgart.
# Extracted 67800 events from Stuttgart.
# Extracted 67900 events from Stuttgart.
# Extracted 68000 events from Stuttgart.
# Extracted 68100 events from Stuttgart.
# Extracted 68200 events from Stuttgart.
# Extracted 68300 events from Stuttgart.
# Extracted 68400 events from Stuttgart.
# Extracted 68500 events from Stuttgart.
# Extracted 68600 events from Stuttgart.
# Extracted 68700 events from Stuttgart.
# Extracted 68800 events from Stuttgart.
# Extracted 68900 events from Stuttgart.
# Extracted 69000 events from Stuttgart.
# Extracted 69100 events from Stuttgart.
# Extracted 69200 events from Stuttgart.
# Extracted 69300 events from Stuttgart.
# Extracted 69400 events from Stuttgart.
# Extracted 69500 events from Stuttgart.
# Extracted 69600 events from Stuttgart.
# Extracted 69700 events from Stuttgart.
# Extracted 69800 events from Stuttgart.
# Extracted 69900 events from Stuttgart.
# Extracted 70000 events from Stuttgart.
# Extracted 70100 events from Stuttgart.
# Extracted 70200 events from Stuttgart.
# Extracted 70300 events from Stuttgart.
# Extracted 70400 events from Stuttgart.
# Extracted 70500 events from Stuttgart.
# Extracted 70600 events from Stuttgart.
# Extracted 70700 events from Stuttgart.
# Extracted 70800 events from Stuttgart.
# Extracted 70900 events from Stuttgart.
# Extracted 71000 events from Stuttgart.
# Extracted 71100 events from Stuttgart.
# Extracted 71200 events from Stuttgart.
# Extracted 71300 events from Stuttgart.
# Extracted 71400 events from Stuttgart.
# Extracted 71500 events from Stuttgart.
# Extracted 71600 events from Stuttgart.
# Extracted 71700 events from Stuttgart.
# Extracted 71800 events from Stuttgart.
# Extracted 71900 events from Stuttgart.
# Extracted 72000 events from Stuttgart.
# Extracted 72100 events from Stuttgart.
# Extracted 72200 events from Stuttgart.
# Extracted 72300 events from Stuttgart.
# Extracted 72400 events from Stuttgart.
# Extracted 72500 events from Stuttgart.
# Extracted 72600 events from Stuttgart.
# Extracted 72700 events from Stuttgart.
# Extracted 72800 events from Stuttgart.
# Extracted 72900 events from Stuttgart.
# Extracted 73000 events from Stuttgart.
# Extracted 73100 events from Stuttgart.
# Extracted 73200 events from Stuttgart.
# Extracted 73300 events from Stuttgart.
# Extracted 73400 events from Stuttgart.
# Extracted 73500 events from Stuttgart.
# Extracted 73600 events from Stuttgart.
# Extracted 73700 events from Stuttgart.
# Extracted 73800 events from Stuttgart.
# Extracted 73900 events from Stuttgart.
# Extracted 74000 events from Stuttgart.
# Extracted 74100 events from Stuttgart.
# Extracted 74200 events from Stuttgart.
# Extracted 74300 events from Stuttgart.
# Extracted 74400 events from Stuttgart.
# Extracted 74500 events from Stuttgart.
# Extracted 74600 events from Stuttgart.
# Extracted 74700 events from Stuttgart.
# Extracted 74800 events from Stuttgart.
# Extracted 74900 events from Stuttgart.
# Extracted 75000 events from Stuttgart.
# Extracted 75100 events from Stuttgart.
# Extracted 75200 events from Stuttgart.
# Extracted 75300 events from Stuttgart.
# Extracted 75400 events from Stuttgart.
# Extracted 75500 events from Stuttgart.
# Extracted 75600 events from Stuttgart.
# Extracted 75700 events from Stuttgart.
# Extracted 75800 events from Stuttgart.
# Extracted 75900 events from Stuttgart.
# Extracted 76000 events from Stuttgart.
# Extracted 76100 events from Stuttgart.
# Extracted 76200 events from Stuttgart.
# Extracted 76300 events from Stuttgart.
# Extracted 76400 events from Stuttgart.
# Extracted 76500 events from Stuttgart.
# Extracted 76600 events from Stuttgart.
# Extracted 76700 events from Stuttgart.
# Extracted 76800 events from Stuttgart.
# Extracted 76900 events from Stuttgart.
# Extracted 77000 events from Stuttgart.
# Extracted 77100 events from Stuttgart.
# Extracted 77200 events from Stuttgart.
# Extracted 77300 events from Stuttgart.
# Extracted 77400 events from Stuttgart.
# Extracted 77500 events from Stuttgart.
# Extracted 77600 events from Stuttgart.
# Extracted 77700 events from Stuttgart.
# Extracted 77800 events from Stuttgart.
# Extracted 77900 events from Stuttgart.
# Extracted 78000 events from Stuttgart.
# Extracted 78100 events from Stuttgart.
# Extracted 78200 events from Stuttgart.
# Extracted 78300 events from Stuttgart.
# Extracted 78400 events from Stuttgart.
# Extracted 78500 events from Stuttgart.
# Extracted 78600 events from Stuttgart.
# Extracted 78700 events from Stuttgart.
# Extracted 78800 events from Stuttgart.
# Extracted 78900 events from Stuttgart.
# Extracted 79000 events from Stuttgart.
# Extracted 79100 events from Stuttgart.
# Extracted 79200 events from Stuttgart.
# Extracted 79300 events from Stuttgart.
# Extracted 79400 events from Stuttgart.
# Extracted 79500 events from Stuttgart.
# Extracted 79600 events from Stuttgart.
# Extracted 79700 events from Stuttgart.
# Extracted 79800 events from Stuttgart.
# Extracted 79900 events from Stuttgart.
# Extracted 80000 events from Stuttgart.
# Extracted 80100 events from Stuttgart.
# Extracted 80200 events from Stuttgart.
# Extracted 80300 events from Stuttgart.
# Extracted 80400 events from Stuttgart.
# Extracted 80500 events from Stuttgart.
# Extracted 80600 events from Stuttgart.
# Extracted 80700 events from Stuttgart.
# Extracted 80800 events from Stuttgart.
# Extracted 80900 events from Stuttgart.
# Extracted 81000 events from Stuttgart.
# Extracted 81100 events from Stuttgart.
# Extracted 81200 events from Stuttgart.
# Extracted 81300 events from Stuttgart.
# Extracted 81400 events from Stuttgart.
# Extracted 81500 events from Stuttgart.
# Extracted 81600 events from Stuttgart.
# Extracted 81700 events from Stuttgart.
# Extracted 81800 events from Stuttgart.
# Extracted 81900 events from Stuttgart.
# Extracted 82000 events from Stuttgart.
# Extracted 82100 events from Stuttgart.
# Extracted 82200 events from Stuttgart.
# Extracted 82300 events from Stuttgart.
# Extracted 82400 events from Stuttgart.
# Extracted 82500 events from Stuttgart.
# Extracted 82600 events from Stuttgart.
# Extracted 82700 events from Stuttgart.
# Extracted 82800 events from Stuttgart.
# Extracted 82900 events from Stuttgart.
# Extracted 83000 events from Stuttgart.
# Extracted 83100 events from Stuttgart.
# Extracted 83200 events from Stuttgart.
# Extracted 83300 events from Stuttgart.
# Extracted 83400 events from Stuttgart.
# Extracted 83500 events from Stuttgart.
# Extracted 83600 events from Stuttgart.
# Extracted 83700 events from Stuttgart.
# Extracted 83800 events from Stuttgart.
# Extracted 83900 events from Stuttgart.
# Extracted 84000 events from Stuttgart.
# Extracted 84100 events from Stuttgart.
# Extracted 84200 events from Stuttgart.
# Extracted 84300 events from Stuttgart.
# Extracted 84400 events from Stuttgart.
# Extracted 84500 events from Stuttgart.
# Extracted 84600 events from Stuttgart.
# Extracted 84700 events from Stuttgart.
# Extracted 84800 events from Stuttgart.
# Extracted 84900 events from Stuttgart.
# Extracted 85000 events from Stuttgart.
# Extracted 85100 events from Stuttgart.
# Extracted 85200 events from Stuttgart.
# Extracted 85300 events from Stuttgart.
# Extracted 85400 events from Stuttgart.
# Extracted 85500 events from Stuttgart.
# Extracted 85600 events from Stuttgart.
# Extracted 85700 events from Stuttgart.
# Extracted 85800 events from Stuttgart.
# Extracted 85900 events from Stuttgart.
# Extracted 86000 events from Stuttgart.
# Extracted 86100 events from Stuttgart.
# Extracted 86200 events from Stuttgart.
# Extracted 86300 events from Stuttgart.
# Extracted 86400 events from Stuttgart.
# Extracted 86500 events from Stuttgart.
# Extracted 86600 events from Stuttgart.
# Extracted 86700 events from Stuttgart.
# Extracted 86800 events from Stuttgart.
# Extracted 86900 events from Stuttgart.
# Extracted 87000 events from Stuttgart.
# Extracted 87100 events from Stuttgart.
# Extracted 87200 events from Stuttgart.
# Extracted 87300 events from Stuttgart.
# Extracted 87400 events from Stuttgart.
# Extracted 87500 events from Stuttgart.
# Extracted 87600 events from Stuttgart.
# Extracted 87700 events from Stuttgart.
# Extracted 87800 events from Stuttgart.
# Extracted 87900 events from Stuttgart.
# Extracted 88000 events from Stuttgart.
# Extracted 88100 events from Stuttgart.
# Extracted 88200 events from Stuttgart.
# Extracted 88300 events from Stuttgart.
# Extracted 88400 events from Stuttgart.
# Extracted 88500 events from Stuttgart.
# Extracted 88600 events from Stuttgart.
# Extracted 88700 events from Stuttgart.
# Extracted 88800 events from Stuttgart.
# Extracted 88900 events from Stuttgart.
# Extracted 89000 events from Stuttgart.
# Extracted 89100 events from Stuttgart.
# Extracted 89200 events from Stuttgart.
# Extracted 89300 events from Stuttgart.
# Extracted 89400 events from Stuttgart.
# Extracted 89500 events from Stuttgart.
# Extracted 89600 events from Stuttgart.
# Extracted 89700 events from Stuttgart.
# Extracted 89800 events from Stuttgart.
# Extracted 89900 events from Stuttgart.
# Extracted 90000 events from Stuttgart.
# Extracted 90100 events from Stuttgart.
# Extracted 90200 events from Stuttgart.
# Extracted 90300 events from Stuttgart.
# Extracted 90400 events from Stuttgart.
# Extracted 90500 events from Stuttgart.
# Extracted 90600 events from Stuttgart.
# Extracted 90700 events from Stuttgart.
# Extracted 90800 events from Stuttgart.
# Extracted 90900 events from Stuttgart.
# Extracted 91000 events from Stuttgart.
# Extracted 91100 events from Stuttgart.
# Extracted 91200 events from Stuttgart.
# Extracted 91300 events from Stuttgart.
# Extracted 91400 events from Stuttgart.
# Extracted 91500 events from Stuttgart.
# Extracted 91600 events from Stuttgart.
# Extracted 91700 events from Stuttgart.
# Extracted 91800 events from Stuttgart.
# Extracted 91900 events from Stuttgart.
# Extracted 92000 events from Stuttgart.
# Extracted 92100 events from Stuttgart.
# Extracted 92200 events from Stuttgart.
# Extracted 92300 events from Stuttgart.
# Extracted 92400 events from Stuttgart.
# Extracted 92500 events from Stuttgart.
# Extracted 92600 events from Stuttgart.
# Extracted 92700 events from Stuttgart.
# Extracted 92800 events from Stuttgart.
# Extracted 92900 events from Stuttgart.
# Extracted 93000 events from Stuttgart.
# Extracted 93100 events from Stuttgart.
# Extracted 93200 events from Stuttgart.
# Extracted 93300 events from Stuttgart.
# Extracted 93400 events from Stuttgart.
# Extracted 93500 events from Stuttgart.
# Extracted 93600 events from Stuttgart.
# Extracted 93700 events from Stuttgart.
# Extracted 93800 events from Stuttgart.
# Extracted 93900 events from Stuttgart.
# Extracted 94000 events from Stuttgart.
# Extracted 94100 events from Stuttgart.
# Extracted 94200 events from Stuttgart.
# Extracted 94300 events from Stuttgart.
# Extracted 94400 events from Stuttgart.
# Extracted 94500 events from Stuttgart.
# Extracted 94600 events from Stuttgart.
# Extracted 94700 events from Stuttgart.
# Extracted 94800 events from Stuttgart.
# Extracted 94900 events from Stuttgart.
# Extracted 95000 events from Stuttgart.
# Extracted 95100 events from Stuttgart.
# Extracted 95200 events from Stuttgart.
# Extracted 95300 events from Stuttgart.
# Extracted 95400 events from Stuttgart.
# Extracted 95500 events from Stuttgart.
# Extracted 95600 events from Stuttgart.
# Extracted 95700 events from Stuttgart.
# Extracted 95800 events from Stuttgart.
# Extracted 95900 events from Stuttgart.
# Extracted 96000 events from Stuttgart.
# Extracted 96100 events from Stuttgart.
# Extracted 96200 events from Stuttgart.
# Extracted 96300 events from Stuttgart.
# Extracted 96400 events from Stuttgart.
# Extracted 96500 events from Stuttgart.
# Extracted 96600 events from Stuttgart.
# Extracted 96700 events from Stuttgart.
# Extracted 96800 events from Stuttgart.
# Extracted 96900 events from Stuttgart.
# Extracted 97000 events from Stuttgart.
# Extracted 97100 events from Stuttgart.
# Extracted 97200 events from Stuttgart.
# Extracted 97300 events from Stuttgart.
# Extracted 97400 events from Stuttgart.
# Extracted 97500 events from Stuttgart.
# Extracted 97600 events from Stuttgart.
# Extracted 97700 events from Stuttgart.
# Extracted 97800 events from Stuttgart.
# Extracted 97900 events from Stuttgart.
# Extracted 98000 events from Stuttgart.
# Extracted 98100 events from Stuttgart.
# Extracted 98200 events from Stuttgart.
# Extracted 98300 events from Stuttgart.
# Extracted 98400 events from Stuttgart.
# Extracted 98500 events from Stuttgart.
# Extracted 98600 events from Stuttgart.
# Extracted 98700 events from Stuttgart.
# Extracted 98800 events from Stuttgart.
# Extracted 98900 events from Stuttgart.
# Extracted 99000 events from Stuttgart.
# Extracted 99100 events from Stuttgart.
# Extracted 99200 events from Stuttgart.
# Extracted 99300 events from Stuttgart.
# Extracted 99400 events from Stuttgart.
# Extracted 99500 events from Stuttgart.
# Extracted 99600 events from Stuttgart.
# Extracted 99700 events from Stuttgart.
# Extracted 99800 events from Stuttgart.
# Extracted 99900 events from Stuttgart.
# Extracted 100000 events from Stuttgart.
# Extracted 100100 events from Stuttgart.
# Extracted 100200 events from Stuttgart.
# Extracted 100300 events from Stuttgart.
# Extracted 100400 events from Stuttgart.
# Extracted 100500 events from Stuttgart.
# Extracted 100600 events from Stuttgart.
# Extracted 100700 events from Stuttgart.
# Extracted 100800 events from Stuttgart.
# Extracted 100900 events from Stuttgart.
# Extracted 101000 events from Stuttgart.
# Extracted 101100 events from Stuttgart.
# Extracted 101200 events from Stuttgart.
# Extracted 101300 events from Stuttgart.
# Extracted 101400 events from Stuttgart.
# Extracted 101500 events from Stuttgart.
# Extracted 101600 events from Stuttgart.
# Extracted 101700 events from Stuttgart.
# Extracted 101800 events from Stuttgart.
# Extracted 101900 events from Stuttgart.
# Extracted 102000 events from Stuttgart.
# Extracted 102100 events from Stuttgart.
# Extracted 102200 events from Stuttgart.
# Extracted 102300 events from Stuttgart.
# Extracted 102400 events from Stuttgart.
# Extracted 102500 events from Stuttgart.
# Extracted 102600 events from Stuttgart.
# Extracted 102700 events from Stuttgart.
# Extracted 102800 events from Stuttgart.
# Extracted 102900 events from Stuttgart.
# Extracted 103000 events from Stuttgart.
# Extracted 103100 events from Stuttgart.
# Extracted 103200 events from Stuttgart.
# Extracted 103300 events from Stuttgart.
# Extracted 103400 events from Stuttgart.
# Extracted 103500 events from Stuttgart.
# Extracted 103600 events from Stuttgart.
# Extracted 103700 events from Stuttgart.
# Extracted 103800 events from Stuttgart.
# Extracted 103900 events from Stuttgart.
# Extracted 104000 events from Stuttgart.
# Extracted 104100 events from Stuttgart.
# Extracted 104200 events from Stuttgart.
# Extracted 104300 events from Stuttgart.
# Extracted 104400 events from Stuttgart.
# Extracted 104500 events from Stuttgart.
# Extracted 104600 events from Stuttgart.
# Extracted 104700 events from Stuttgart.
# Extracted 104800 events from Stuttgart.
# Extracted 104900 events from Stuttgart.
# Extracted 105000 events from Stuttgart.
# Extracted 105100 events from Stuttgart.
# Extracted 105200 events from Stuttgart.
# Extracted 105300 events from Stuttgart.
# Extracted 105400 events from Stuttgart.
# Extracted 105500 events from Stuttgart.
# Extracted 105600 events from Stuttgart.
# Extracted 105700 events from Stuttgart.
# Extracted 105800 events from Stuttgart.
# Extracted 105900 events from Stuttgart.
# Extracted 106000 events from Stuttgart.
# Extracted 106100 events from Stuttgart.
# Extracted 106200 events from Stuttgart.
# Extracted 106300 events from Stuttgart.
# Extracted 106400 events from Stuttgart.
# Extracted 106500 events from Stuttgart.
# Extracted 106600 events from Stuttgart.
# Extracted 106700 events from Stuttgart.
# Extracted 106800 events from Stuttgart.
# Extracted 106900 events from Stuttgart.
# Extracted 107000 events from Stuttgart.
# Extracted 107100 events from Stuttgart.
# Extracted 107200 events from Stuttgart.
# Extracted 107300 events from Stuttgart.
# Extracted 107400 events from Stuttgart.
# Extracted 107500 events from Stuttgart.
# Extracted 107600 events from Stuttgart.
# Extracted 107700 events from Stuttgart.
# Extracted 107800 events from Stuttgart.
# Extracted 107900 events from Stuttgart.
# Extracted 108000 events from Stuttgart.
# Extracted 108100 events from Stuttgart.
# Extracted 108200 events from Stuttgart.
# Extracted 108300 events from Stuttgart.
# Extracted 108400 events from Stuttgart.
# Extracted 108500 events from Stuttgart.
# Extracted 108600 events from Stuttgart.
# Extracted 108700 events from Stuttgart.
# Extracted 108800 events from Stuttgart.
# Extracted 108900 events from Stuttgart.
# Extracted 109000 events from Stuttgart.
# Extracted 109100 events from Stuttgart.
# Extracted 109200 events from Stuttgart.
# Extracted 109300 events from Stuttgart.
# Extracted 109400 events from Stuttgart.
# Extracted 109500 events from Stuttgart.
# Extracted 109600 events from Stuttgart.
# Extracted 109700 events from Stuttgart.
# Extracted 109800 events from Stuttgart.
# Extracted 109900 events from Stuttgart.
# Extracted 110000 events from Stuttgart.
# Extracted 110100 events from Stuttgart.
# Extracted 110200 events from Stuttgart.
# Extracted 110300 events from Stuttgart.
# Extracted 110400 events from Stuttgart.
# Extracted 110500 events from Stuttgart.
# Extracted 110600 events from Stuttgart.
# Extracted 110700 events from Stuttgart.
# Extracted 110800 events from Stuttgart.
# Extracted 110900 events from Stuttgart.
# Extracted 111000 events from Stuttgart.
# Extracted 111100 events from Stuttgart.
# Extracted 111200 events from Stuttgart.
# Extracted 111300 events from Stuttgart.
# Extracted 111400 events from Stuttgart.
# Extracted 111500 events from Stuttgart.
# Extracted 111600 events from Stuttgart.
# Extracted 111700 events from Stuttgart.
# Extracted 111800 events from Stuttgart.
# Extracted 111900 events from Stuttgart.
# Extracted 112000 events from Stuttgart.
# Extracted 112100 events from Stuttgart.
# Extracted 112200 events from Stuttgart.
# Extracted 112300 events from Stuttgart.
# Extracted 112400 events from Stuttgart.
# Extracted 112500 events from Stuttgart.
# Extracted 112600 events from Stuttgart.
# Extracted 112700 events from Stuttgart.
# Extracted 112800 events from Stuttgart.
# Extracted 112900 events from Stuttgart.
# Extracted 113000 events from Stuttgart.
# Extracted 113100 events from Stuttgart.
# Extracted 113200 events from Stuttgart.
# Extracted 113300 events from Stuttgart.
# Extracted 113400 events from Stuttgart.
# Extracted 113500 events from Stuttgart.
# Extracted 113600 events from Stuttgart.
# Extracted 113700 events from Stuttgart.
# Extracted 113800 events from Stuttgart.
# Extracted 113900 events from Stuttgart.
# Extracted 114000 events from Stuttgart.
# Extracted 114100 events from Stuttgart.
# Extracted 114200 events from Stuttgart.
# Extracted 114300 events from Stuttgart.
# Extracted 114400 events from Stuttgart.
# Extracted 114500 events from Stuttgart.
# Extracted 114600 events from Stuttgart.
# Extracted 114700 events from Stuttgart.
# Extracted 114800 events from Stuttgart.
# Extracted 114900 events from Stuttgart.
# Extracted 115000 events from Stuttgart.
# Extracted 115100 events from Stuttgart.
# Extracted 115200 events from Stuttgart.
# Extracted 115300 events from Stuttgart.
# Extracted 115400 events from Stuttgart.
# Extracted 115500 events from Stuttgart.
# Extracted 115600 events from Stuttgart.
# Extracted 115700 events from Stuttgart.
# Extracted 115800 events from Stuttgart.
# Extracted 115900 events from Stuttgart.
# Extracted 116000 events from Stuttgart.
# Extracted 116100 events from Stuttgart.
# Extracted 116200 events from Stuttgart.
# Extracted 116300 events from Stuttgart.
# Extracted 116400 events from Stuttgart.
# Extracted 116500 events from Stuttgart.
# Extracted 116600 events from Stuttgart.
# Extracted 116700 events from Stuttgart.
# Extracted 116800 events from Stuttgart.
# Extracted 116900 events from Stuttgart.
# Extracted 117000 events from Stuttgart.
# Extracted 117100 events from Stuttgart.
# Extracted 117200 events from Stuttgart.
# Extracted 117300 events from Stuttgart.
# Extracted 117400 events from Stuttgart.
# Extracted 117500 events from Stuttgart.
# Extracted 117600 events from Stuttgart.
# Extracted 117700 events from Stuttgart.
# Extracted 117800 events from Stuttgart.
# Extracted 117900 events from Stuttgart.
# Extracted 118000 events from Stuttgart.
# Extracted 118100 events from Stuttgart.
# Extracted 118200 events from Stuttgart.
# Extracted 118300 events from Stuttgart.
# Extracted 118400 events from Stuttgart.
# Extracted 118500 events from Stuttgart.
# Extracted 118600 events from Stuttgart.
# Extracted 118700 events from Stuttgart.
# Extracted 118800 events from Stuttgart.
# Extracted 118900 events from Stuttgart.
# Extracted 119000 events from Stuttgart.
# Extracted 119100 events from Stuttgart.
# Extracted 119200 events from Stuttgart.
# Extracted 119300 events from Stuttgart.
# Extracted 119400 events from Stuttgart.
# Extracted 119500 events from Stuttgart.
# Extracted 119600 events from Stuttgart.
# Extracted 119700 events from Stuttgart.
# Extracted 119800 events from Stuttgart.
# Extracted 119900 events from Stuttgart.
# Extracted 120000 events from Stuttgart.
# Extracted 120100 events from Stuttgart.
# Extracted 120200 events from Stuttgart.
# Extracted 120300 events from Stuttgart.
# Extracted 120400 events from Stuttgart.
# Extracted 120500 events from Stuttgart.
# Extracted 120600 events from Stuttgart.
# Extracted 120700 events from Stuttgart.
# Extracted 120800 events from Stuttgart.
# Extracted 120900 events from Stuttgart.
# Extracted 121000 events from Stuttgart.
# Extracted 121100 events from Stuttgart.
# Extracted 121200 events from Stuttgart.
# Extracted 121300 events from Stuttgart.
# Extracted 121400 events from Stuttgart.
# Extracted 121500 events from Stuttgart.
# Extracted 121600 events from Stuttgart.
# Extracted 121700 events from Stuttgart.
# Extracted 121800 events from Stuttgart.
# Extracted 121900 events from Stuttgart.
# Extracted 122000 events from Stuttgart.
# Extracted 122100 events from Stuttgart.
# Extracted 122200 events from Stuttgart.
# Extracted 122300 events from Stuttgart.
# Extracted 122400 events from Stuttgart.
# Extracted 122500 events from Stuttgart.
# Extracted 122600 events from Stuttgart.
# ...
# Extracted 239600 events from Stuttgart.
# Extracted 239700 events from Stuttgart.
# Extracted 239800 events from Stuttgart.
# Extracted 239900 events from Stuttgart.
# Extracted 240000 events from Stuttgart.
# Extracted 240100 events from Stuttgart.
# Extracted 240200 events from Stuttgart.
# Extracted 240300 events from Stuttgart.
# Extracted 240400 events from Stuttgart.
# Extracted 240500 events from Stuttgart.
# Extracted 240600 events from Stuttgart.
# Extracted 240700 events from Stuttgart.
# Extracted 240800 events from Stuttgart.
# Extracted 240900 events from Stuttgart.
# Extracted 241000 events from Stuttgart.
# Extracted 241100 events from Stuttgart.
# Extracted 241200 events from Stuttgart.
# Extracted 241300 events from Stuttgart.
# Extracted 241400 events from Stuttgart.
# Extracted 241500 events from Stuttgart.
# Extracted 241600 events from Stuttgart.
# Extracted 241700 events from Stuttgart.
# Extracted 241800 events from Stuttgart.
# Extracted 241900 events from Stuttgart.
# Extracted 242000 events from Stuttgart.
# Extracted 242100 events from Stuttgart.
# Extracted 242200 events from Stuttgart.
# Extracted 242300 events from Stuttgart.
# Extracted 242400 events from Stuttgart.
# Extracted 242500 events from Stuttgart.
# Extracted 242600 events from Stuttgart.
# Extracted 242700 events from Stuttgart.
# Extracted 242800 events from Stuttgart.
# Extracted 242900 events from Stuttgart.
# Extracted 243000 events from Stuttgart.
# Extracted 243100 events from Stuttgart.
# Extracted 243200 events from Stuttgart.
# Extracted 243300 events from Stuttgart.
# Extracted 243400 events from Stuttgart.
# Extracted 243500 events from Stuttgart.
# Extracted 243600 events from Stuttgart.
# Extracted 243700 events from Stuttgart.
# Extracted 243800 events from Stuttgart.
# Extracted 243900 events from Stuttgart.
# Extracted 244000 events from Stuttgart.
# Extracted 244100 events from Stuttgart.
# Extracted 244200 events from Stuttgart.
# Extracted 244300 events from Stuttgart.
# Extracted 244400 events from Stuttgart.
# Extracted 244500 events from Stuttgart.
# Extracted 244600 events from Stuttgart.
# Extracted 244700 events from Stuttgart.
# Extracted 244800 events from Stuttgart.
# Extracted 244900 events from Stuttgart.
# Extracted 245000 events from Stuttgart.
# Extracted 245100 events from Stuttgart.
# Extracted 245200 events from Stuttgart.
# Extracted 245300 events from Stuttgart.
# Extracted 245400 events from Stuttgart.
# Extracted 245500 events from Stuttgart.
# Extracted 245600 events from Stuttgart.
# Extracted 245700 events from Stuttgart.
# Extracted 245800 events from Stuttgart.
# Extracted 245900 events from Stuttgart.
# Extracted 246000 events from Stuttgart.
# Extracted 246100 events from Stuttgart.
# Extracted 246200 events from Stuttgart.
# Extracted 246300 events from Stuttgart.
# Extracted 246400 events from Stuttgart.
# Extracted 246500 events from Stuttgart.
# Extracted 246600 events from Stuttgart.
# Extracted 246700 events from Stuttgart.
# Extracted 246800 events from Stuttgart.
# Extracted 246900 events from Stuttgart.
# Extracted 247000 events from Stuttgart.
# Extracted 247100 events from Stuttgart.
# Extracted 247200 events from Stuttgart.
# Extracted 247300 events from Stuttgart.
# Extracted 247400 events from Stuttgart.
# Extracted 247500 events from Stuttgart.
# Extracted 247600 events from Stuttgart.
# Extracted 247700 events from Stuttgart.
# Extracted 247800 events from Stuttgart.
# Extracted 247900 events from Stuttgart.
# Extracted 248000 events from Stuttgart.
# Extracted 248100 events from Stuttgart.
# Extracted 248200 events from Stuttgart.
# Extracted 248300 events from Stuttgart.
# Extracted 248400 events from Stuttgart.
# Extracted 248500 events from Stuttgart.
# Extracted 248600 events from Stuttgart.
# Extracted 248700 events from Stuttgart.
# Extracted 248800 events from Stuttgart.
# Extracted 248900 events from Stuttgart.
# Extracted 249000 events from Stuttgart.
# Extracted 249100 events from Stuttgart.
# Extracted 249200 events from Stuttgart.
# Extracted 249300 events from Stuttgart.
# Extracted 249400 events from Stuttgart.
# Extracted 249500 events from Stuttgart.
# Extracted 249600 events from Stuttgart.
# Extracted 249700 events from Stuttgart.
# Extracted 249800 events from Stuttgart.
# Extracted 249900 events from Stuttgart.
# Extracted 250000 events from Stuttgart.
# Extracted 250100 events from Stuttgart.
# Extracted 250200 events from Stuttgart.
# Extracted 250300 events from Stuttgart.
# Extracted 250400 events from Stuttgart.
# Extracted 250500 events from Stuttgart.
# Extracted 250600 events from Stuttgart.
# Extracted 250700 events from Stuttgart.
# Extracted 250800 events from Stuttgart.
# Extracted 250900 events from Stuttgart.
# Extracted 251000 events from Stuttgart.
# Extracted 251100 events from Stuttgart.
# Extracted 251200 events from Stuttgart.
# Extracted 251300 events from Stuttgart.
# Extracted 251400 events from Stuttgart.
# Extracted 251500 events from Stuttgart.
# Extracted 251600 events from Stuttgart.
# Extracted 251700 events from Stuttgart.
# Extracted 251800 events from Stuttgart.
# Extracted 251900 events from Stuttgart.
# Extracted 252000 events from Stuttgart.
# Extracted 252100 events from Stuttgart.
# Extracted 252200 events from Stuttgart.
# Extracted 252300 events from Stuttgart.
# Extracted 252400 events from Stuttgart.
# Extracted 252500 events from Stuttgart.
# Extracted 252600 events from Stuttgart.
# Extracted 252700 events from Stuttgart.
# Extracted 252800 events from Stuttgart.
# Extracted 252900 events from Stuttgart.
# Extracted 253000 events from Stuttgart.
# Extracted 253100 events from Stuttgart.
# Extracted 253200 events from Stuttgart.
# Extracted 253300 events from Stuttgart.
# Extracted 253400 events from Stuttgart.
# Extracted 253500 events from Stuttgart.
# Extracted 253600 events from Stuttgart.
# Extracted 253700 events from Stuttgart.
# Extracted 253800 events from Stuttgart.
# Extracted 253900 events from Stuttgart.
# Extracted 254000 events from Stuttgart.
# Extracted 254100 events from Stuttgart.
# Extracted 254200 events from Stuttgart.
# Extracted 254300 events from Stuttgart.
# Extracted 254400 events from Stuttgart.
# Extracted 254500 events from Stuttgart.
# Extracted 254600 events from Stuttgart.
# Extracted 254700 events from Stuttgart.
# Extracted 254800 events from Stuttgart.
# Extracted 254900 events from Stuttgart.
# Extracted 255000 events from Stuttgart.
# Extracted 255100 events from Stuttgart.
# Extracted 255200 events from Stuttgart.
# Extracted 255300 events from Stuttgart.
# Extracted 255400 events from Stuttgart.
# Extracted 255500 events from Stuttgart.
# Extracted 255600 events from Stuttgart.
# Extracted 255700 events from Stuttgart.
# Extracted 255800 events from Stuttgart.
# Extracted 255900 events from Stuttgart.
# Extracted 256000 events from Stuttgart.
# Extracted 256100 events from Stuttgart.
# Extracted 256200 events from Stuttgart.
# Extracted 256300 events from Stuttgart.
# Extracted 256400 events from Stuttgart.
# Extracted 256500 events from Stuttgart.
# Extracted 256600 events from Stuttgart.
# Extracted 256700 events from Stuttgart.
# Extracted 256800 events from Stuttgart.
# Extracted 256900 events from Stuttgart.
# Extracted 257000 events from Stuttgart.
# Extracted 257100 events from Stuttgart.
# Extracted 257200 events from Stuttgart.
# Extracted 257300 events from Stuttgart.
# Extracted 257400 events from Stuttgart.
# Extracted 257500 events from Stuttgart.
# Extracted 257600 events from Stuttgart.
# Extracted 257700 events from Stuttgart.
# Extracted 257800 events from Stuttgart.
# Extracted 257900 events from Stuttgart.
# Extracted 258000 events from Stuttgart.
# Extracted 258100 events from Stuttgart.
# Extracted 258200 events from Stuttgart.
# Extracted 258300 events from Stuttgart.
# Extracted 258400 events from Stuttgart.
# Extracted 258500 events from Stuttgart.
# Extracted 258600 events from Stuttgart.
# Extracted 258700 events from Stuttgart.
# Extracted 258800 events from Stuttgart.
# Extracted 258900 events from Stuttgart.
# Extracted 259000 events from Stuttgart.
# Extracted 259100 events from Stuttgart.
# Extracted 259200 events from Stuttgart.
# Extracted 259300 events from Stuttgart.
# Extracted 259400 events from Stuttgart.
# Extracted 259500 events from Stuttgart.
# Extracted 259600 events from Stuttgart.
# Extracted 259700 events from Stuttgart.
# Extracted 259800 events from Stuttgart.
# Extracted 259900 events from Stuttgart.
# Extracted 260000 events from Stuttgart.
# Extracted 260100 events from Stuttgart.
# Extracted 260200 events from Stuttgart.
# Extracted 260300 events from Stuttgart.
# Extracted 260400 events from Stuttgart.
# Extracted 260500 events from Stuttgart.
# Extracted 260600 events from Stuttgart.
# Extracted 260700 events from Stuttgart.
# Extracted 260800 events from Stuttgart.
# Extracted 260900 events from Stuttgart.
# Extracted 261000 events from Stuttgart.
# Extracted 261100 events from Stuttgart.
# Extracted 261200 events from Stuttgart.
# Extracted 261300 events from Stuttgart.
# Extracted 261400 events from Stuttgart.
# Extracted 261500 events from Stuttgart.
# Extracted 261600 events from Stuttgart.
# Extracted 261700 events from Stuttgart.
# Extracted 261800 events from Stuttgart.
# Extracted 261900 events from Stuttgart.
# Extracted 262000 events from Stuttgart.
# Extracted 262100 events from Stuttgart.
# Extracted 262200 events from Stuttgart.
# Extracted 262300 events from Stuttgart.
# Extracted 262400 events from Stuttgart.
# Extracted 262500 events from Stuttgart.
# Extracted 262600 events from Stuttgart.
# Extracted 262700 events from Stuttgart.
# Extracted 262800 events from Stuttgart.
# Extracted 262900 events from Stuttgart.
# Extracted 263000 events from Stuttgart.
# Extracted 263100 events from Stuttgart.
# Extracted 263200 events from Stuttgart.
# Extracted 263300 events from Stuttgart.
# Extracted 263400 events from Stuttgart.
# Extracted 263500 events from Stuttgart.
# Extracted 263600 events from Stuttgart.
# Extracted 263700 events from Stuttgart.
# Extracted 263800 events from Stuttgart.
# Extracted 263900 events from Stuttgart.
# Extracted 264000 events from Stuttgart.
# Extracted 264100 events from Stuttgart.
# Extracted 264200 events from Stuttgart.
# Extracted 264300 events from Stuttgart.
# Extracted 0 events from Stuttgart.
# Extracted 100 events from Stuttgart.
# Extracted 200 events from Stuttgart.
# Extracted 300 events from Stuttgart.
# Extracted 400 events from Stuttgart.
# Extracted 500 events from Stuttgart.
# Extracted 600 events from Stuttgart.
# Extracted 700 events from Stuttgart.
# Extracted 800 events from Stuttgart.
# Extracted 900 events from Stuttgart.
# Extracted 1000 events from Stuttgart.
# Extracted 1100 events from Stuttgart.
# Extracted 1200 events from Stuttgart.
# Extracted 1300 events from Stuttgart.
# Extracted 1400 events from Stuttgart.
# Extracted 1500 events from Stuttgart.
# Extracted 1600 events from Stuttgart.
# Extracted 1700 events from Stuttgart.
# Extracted 1800 events from Stuttgart.
# Extracted 1900 events from Stuttgart.
# Extracted 2000 events from Stuttgart.
# Extracted 2100 events from Stuttgart.
# Extracted 2200 events from Stuttgart.
# Extracted 2300 events from Stuttgart.
# Extracted 2400 events from Stuttgart.
# Extracted 2500 events from Stuttgart.
# Extracted 2600 events from Stuttgart.
# Extracted 2700 events from Stuttgart.
# Extracted 2800 events from Stuttgart.
# Extracted 2900 events from Stuttgart.
# Extracted 3000 events from Stuttgart.
# Extracted 3100 events from Stuttgart.
# Extracted 3200 events from Stuttgart.
# Extracted 3300 events from Stuttgart.
# Extracted 3400 events from Stuttgart.
# Extracted 3500 events from Stuttgart.
# Extracted 3600 events from Stuttgart.
# Extracted 3700 events from Stuttgart.
# Extracted 3800 events from Stuttgart.
# Extracted 3900 events from Stuttgart.
# Extracted 4000 events from Stuttgart.
# Extracted 4100 events from Stuttgart.
# Extracted 4200 events from Stuttgart.
# Extracted 4300 events from Stuttgart.
# Extracted 4400 events from Stuttgart.
# Extracted 4500 events from Stuttgart.
# Extracted 4600 events from Stuttgart.
# Extracted 4700 events from Stuttgart.
# Extracted 4800 events from Stuttgart.
# Extracted 4900 events from Stuttgart.
# Extracted 5000 events from Stuttgart.
# Extracted 5100 events from Stuttgart.
# Extracted 5200 events from Stuttgart.
# Extracted 5300 events from Stuttgart.
# Extracted 5400 events from Stuttgart.
# Extracted 5500 events from Stuttgart.
# Extracted 5600 events from Stuttgart.
# Extracted 5700 events from Stuttgart.
# Extracted 5800 events from Stuttgart.
# Extracted 5900 events from Stuttgart.
# Extracted 6000 events from Stuttgart.
# Extracted 6100 events from Stuttgart.
# Extracted 6200 events from Stuttgart.
# Extracted 6300 events from Stuttgart.
# Extracted 6400 events from Stuttgart.
# Extracted 6500 events from Stuttgart.
# Extracted 6600 events from Stuttgart.
# Extracted 6700 events from Stuttgart.
# Extracted 6800 events from Stuttgart.
# Extracted 6900 events from Stuttgart.
# Extracted 7000 events from Stuttgart.
# Extracted 7100 events from Stuttgart.
# Extracted 7200 events from Stuttgart.
# Extracted 7300 events from Stuttgart.
# Extracted 7400 events from Stuttgart.
# Extracted 7500 events from Stuttgart.
# Extracted 7600 events from Stuttgart.
# Extracted 7700 events from Stuttgart.
# Extracted 7800 events from Stuttgart.
# Extracted 7900 events from Stuttgart.
# Extracted 8000 events from Stuttgart.
# Extracted 8100 events from Stuttgart.
# Extracted 8200 events from Stuttgart.
# Extracted 8300 events from Stuttgart.
# Extracted 8400 events from Stuttgart.
# Extracted 8500 events from Stuttgart.
# Extracted 8600 events from Stuttgart.
# Extracted 8700 events from Stuttgart.
# Extracted 8800 events from Stuttgart.
# Extracted 8900 events from Stuttgart.
# Extracted 9000 events from Stuttgart.
# Extracted 9100 events from Stuttgart.
# Extracted 9200 events from Stuttgart.
# Extracted 9300 events from Stuttgart.
# Extracted 9400 events from Stuttgart.
# Extracted 9500 events from Stuttgart.
# Extracted 9600 events from Stuttgart.
# Extracted 9700 events from Stuttgart.
# Extracted 9800 events from Stuttgart.
# Extracted 9900 events from Stuttgart.
# Extracted 10000 events from Stuttgart.
# Extracted 10100 events from Stuttgart.
# Extracted 10200 events from Stuttgart.
# Extracted 10300 events from Stuttgart.
# Extracted 10400 events from Stuttgart.
# Extracted 10500 events from Stuttgart.
# Extracted 10600 events from Stuttgart.
# Extracted 10700 events from Stuttgart.
# Extracted 10800 events from Stuttgart.
# Extracted 10900 events from Stuttgart.
# Extracted 11000 events from Stuttgart.
# Extracted 11100 events from Stuttgart.
# Extracted 11200 events from Stuttgart.
# Extracted 11300 events from Stuttgart.
# Extracted 11400 events from Stuttgart.
# Extracted 11500 events from Stuttgart.
# Extracted 11600 events from Stuttgart.
# Extracted 11700 events from Stuttgart.
# Extracted 11800 events from Stuttgart.
# Extracted 11900 events from Stuttgart.
# Extracted 12000 events from Stuttgart.
# Extracted 12100 events from Stuttgart.
# Extracted 12200 events from Stuttgart.
# Extracted 12300 events from Stuttgart.
# Extracted 12400 events from Stuttgart.
# Extracted 12500 events from Stuttgart.
# Extracted 12600 events from Stuttgart.
# Extracted 12700 events from Stuttgart.
# Extracted 12800 events from Stuttgart.
# Extracted 12900 events from Stuttgart.
# Extracted 13000 events from Stuttgart.
# Extracted 13100 events from Stuttgart.
# Extracted 13200 events from Stuttgart.
# Extracted 13300 events from Stuttgart.
# Extracted 13400 events from Stuttgart.
# Extracted 13500 events from Stuttgart.
# Extracted 13600 events from Stuttgart.
# Extracted 13700 events from Stuttgart.
# Extracted 13800 events from Stuttgart.
# Extracted 13900 events from Stuttgart.
# Extracted 14000 events from Stuttgart.
# Extracted 14100 events from Stuttgart.
# Extracted 14200 events from Stuttgart.
# Extracted 14300 events from Stuttgart.
# Extracted 14400 events from Stuttgart.
# Extracted 14500 events from Stuttgart.
# Extracted 14600 events from Stuttgart.
# Extracted 14700 events from Stuttgart.
# Extracted 14800 events from Stuttgart.
# Extracted 14900 events from Stuttgart.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Data Preprocessing 🧑‍🦯

# %%
def remove_events_not_in_stuttgart(df: pd.DataFrame) -> pd.DataFrame:
    """
    Remove all events not in Stuttgart by looking at the evntData.location.location.city column
    :param df: dataframe containing the events
    :return: dataframe containing only events in Stuttgart (might be the same as inpt df)
    """
    df = df[df['eventData.location.location.address.city'] == 'Stuttgart']
    return df

df = remove_events_not_in_stuttgart(df)

# %%
print(df.shape)

# %% [markdown]
# ### Check for NA values

# %%
# check for NA values
print(df.isna().sum())

# %%
# Create a heatmap of missing values
plt.figure(figsize=(25, 6))  # Adjust the figure size as needed
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# Interpretation: The yellow area shows the NA values. There is a lot of missing data 😨

# %%
# delete columns with more than 10% missing values
df = df[df.columns[df.isnull().mean() < 0.1]]
print(df.shape)
